# %%
from music21 import *
# for listing down the file names
import os
from fractions import *


# Array Processing
import numpy as np

# %%
# defining function to read MIDI files
def read_midi(file):
    print("Loading Music File:", file)
    
    unparsed_notes= []


    # parsing a midi file
    midi_data = converter.parse(file)
    
    for part in midi_data.parts:
        print(part.partName)
        
        if part.partName == 'MELODY':
            notes_to_parse = part.recurse()
            
            unparsed_notes.append(notes_to_parse)
            
            
            


    return np.array(unparsed_notes)

# %%
# specify the path
path = 'POP/'

files = []
limit = 1000


for index, i in enumerate(os.listdir(path)):
    if index == limit:
        break
    for j in os.listdir(path+i):
        file_path = (i+'/'+j)
        if file_path.endswith(".mid"):
            files.append(file_path)
        

print(files)
# Out:
# ['001/001.mid', '002/002.mid', '003/003.mid', '004/004.mid', '005/005.mid', '006/006.mid', '007/007.mid', '008/008.mid', '009/009.mid', '010/010.mid', '011/011.mid', '012/012.mid', '013/013.mid', '014/014.mid', '015/015.mid', '016/016.mid', '017/017.mid', '018/018.mid', '019/019.mid', '020/020.mid', '021/021.mid', '022/022.mid', '023/023.mid', '024/024.mid', '025/025.mid', '026/026.mid', '027/027.mid', '028/028.mid', '029/029.mid', '030/030.mid', '031/031.mid', '032/032.mid', '033/033.mid', '034/034.mid', '035/035.mid', '036/036.mid', '037/037.mid', '038/038.mid', '039/039.mid', '040/040.mid', '041/041.mid', '042/042.mid', '043/043.mid', '044/044.mid', '045/045.mid', '046/046.mid', '047/047.mid', '048/048.mid', '049/049.mid', '050/050.mid', '051/051.mid', '052/052.mid', '053/053.mid', '054/054.mid', '055/055.mid', '056/056.mid', '057/057.mid', '058/058.mid', '059/059.mid', '060/060.mid', '061/061.mid', '062/062.mid', '063/063.mid', '064/064.mid', '065/065.mid', '066/066.mid', '067/067.mid', '068/068.mid', '069/069.mid', '070/070.mid', '071/071.mid', '072/072.mid', '073/073.mid', '074/074.mid', '075/075.mid', '076/076.mid', '077/077.mid', '078/078.mid', '079/079.mid', '080/080.mid', '081/081.mid', '082/082.mid', '083/083.mid', '084/084.mid', '085/085.mid', '086/086.mid', '087/087.mid', '088/088.mid', '089/089.mid', '090/090.mid', '091/091.mid', '092/092.mid', '093/093.mid', '094/094.mid', '095/095.mid', '096/096.mid', '097/097.mid', '098/098.mid', '099/099.mid', '100/100.mid', '101/101.mid', '102/102.mid', '103/103.mid', '104/104.mid', '105/105.mid', '106/106.mid', '107/107.mid', '108/108.mid', '109/109.mid', '110/110.mid', '111/111.mid', '112/112.mid', '113/113.mid', '114/114.mid', '115/115.mid', '116/116.mid', '117/117.mid', '118/118.mid', '119/119.mid', '120/120.mid', '121/121.mid', '122/122.mid', '123/123.mid', '124/124.mid', '125/125.mid', '126/126.mid', '127/127.mid', '128/128.mid', '129/129.mid', '130/130.mid', '131/131.mid', '132/132.mid', '133/133.mid', '134/134.mid', '135/135.mid', '136/136.mid', '137/137.mid', '138/138.mid', '139/139.mid', '140/140.mid', '141/141.mid', '142/142.mid', '143/143.mid', '144/144.mid', '145/145.mid', '146/146.mid', '147/147.mid', '148/148.mid', '149/149.mid', '150/150.mid', '151/151.mid', '152/152.mid', '153/153.mid', '154/154.mid', '155/155.mid', '156/156.mid', '157/157.mid', '158/158.mid', '159/159.mid', '160/160.mid', '161/161.mid', '162/162.mid', '163/163.mid', '164/164.mid', '165/165.mid', '166/166.mid', '167/167.mid', '168/168.mid', '169/169.mid', '170/170.mid', '171/171.mid', '172/172.mid', '173/173.mid', '174/174.mid', '175/175.mid', '176/176.mid', '177/177.mid', '178/178.mid', '179/179.mid', '180/180.mid', '181/181.mid', '182/182.mid', '183/183.mid', '184/184.mid', '185/185.mid', '186/186.mid', '187/187.mid', '188/188.mid', '189/189.mid', '190/190.mid', '191/191.mid', '192/192.mid', '193/193.mid', '194/194.mid', '195/195.mid', '196/196.mid', '197/197.mid', '198/198.mid', '199/199.mid', '200/200.mid']

# %%
# reading each midi file
unparsed_notes_array = []


for index, i in enumerate(files):
    if index == limit:
        break
    unparsed_notes_array.append(read_midi(path + i))
# Out:
# Loading Music File: POP/001/001.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/002/002.mid
# <ipython-input-79-5941b688e3c1>:23: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(unparsed_notes)
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/003/003.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/004/004.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/005/005.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/006/006.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/007/007.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/008/008.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/009/009.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/010/010.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/011/011.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/012/012.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/013/013.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/014/014.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/015/015.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/016/016.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/017/017.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/018/018.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/019/019.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/020/020.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/021/021.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/022/022.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/023/023.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/024/024.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/025/025.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/026/026.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/027/027.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/028/028.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/029/029.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/030/030.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/031/031.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/032/032.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/033/033.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/034/034.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/035/035.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/036/036.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/037/037.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/038/038.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/039/039.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/040/040.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/041/041.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/042/042.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/043/043.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/044/044.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/045/045.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/046/046.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/047/047.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/048/048.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/049/049.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/050/050.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/051/051.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/052/052.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/053/053.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/054/054.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/055/055.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/056/056.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/057/057.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/058/058.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/059/059.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/060/060.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/061/061.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/062/062.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/063/063.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/064/064.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/065/065.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/066/066.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/067/067.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/068/068.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/069/069.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/070/070.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/071/071.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/072/072.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/073/073.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/074/074.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/075/075.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/076/076.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/077/077.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/078/078.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/079/079.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/080/080.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/081/081.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/082/082.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/083/083.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/084/084.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/085/085.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/086/086.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/087/087.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/088/088.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/089/089.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/090/090.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/091/091.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/092/092.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/093/093.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/094/094.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/095/095.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/096/096.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/097/097.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/098/098.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/099/099.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/100/100.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/101/101.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/102/102.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/103/103.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/104/104.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/105/105.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/106/106.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/107/107.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/108/108.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/109/109.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/110/110.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/111/111.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/112/112.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/113/113.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/114/114.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/115/115.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/116/116.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/117/117.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/118/118.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/119/119.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/120/120.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/121/121.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/122/122.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/123/123.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/124/124.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/125/125.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/126/126.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/127/127.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/128/128.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/129/129.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/130/130.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/131/131.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/132/132.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/133/133.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/134/134.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/135/135.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/136/136.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/137/137.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/138/138.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/139/139.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/140/140.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/141/141.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/142/142.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/143/143.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/144/144.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/145/145.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/146/146.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/147/147.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/148/148.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/149/149.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/150/150.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/151/151.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/152/152.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/153/153.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/154/154.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/155/155.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/156/156.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/157/157.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/158/158.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/159/159.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/160/160.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/161/161.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/162/162.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/163/163.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/164/164.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/165/165.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/166/166.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/167/167.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/168/168.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/169/169.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/170/170.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/171/171.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/172/172.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/173/173.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/174/174.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/175/175.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/176/176.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/177/177.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/178/178.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/179/179.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/180/180.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/181/181.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/182/182.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/183/183.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/184/184.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/185/185.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/186/186.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/187/187.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/188/188.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/189/189.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/190/190.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/191/191.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/192/192.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/193/193.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/194/194.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/195/195.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/196/196.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/197/197.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/198/198.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/199/199.mid
# MELODY
# BRIDGE
# PIANO
# Loading Music File: POP/200/200.mid
# MELODY
# BRIDGE
# PIANO

# %%
unparsed_notes_array
# Out:
# [array([[<music21.stream.Measure 1 offset=0.0>,
#          <music21.instrument.Piano 'MELODY: Piano'>,
#          <music21.clef.TrebleClef>,
#          <music21.tempo.MetronomeMark maestoso Quarter=90.0>,
#          <music21.meter.TimeSignature 2/4>, <music21.note.Rest half>,
#          <music21.stream.Measure 2 offset=2.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 3 offset=4.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 4 offset=6.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 5 offset=8.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 6 offset=10.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 7 offset=12.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 8 offset=14.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 9 offset=16.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 10 offset=18.0>,
#          <music21.note.Rest quarter>, <music21.note.Note C#>,
#          <music21.note.Rest 1/12ql>, <music21.note.Note E->,
#          <music21.note.Note F#>, <music21.note.Note G#>,
#          <music21.stream.Measure 11 offset=20.0>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.stream.Measure 12 offset=22.0>, <music21.note.Note G#>,
#          <music21.note.Rest quarter>,
#          <music21.stream.Measure 13 offset=24.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note F>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.stream.Measure 14 offset=26.0>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 1/12ql>, <music21.note.Note E->,
#          <music21.note.Note F#>, <music21.note.Note G#>,
#          <music21.stream.Measure 15 offset=28.0>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.stream.Measure 16 offset=30.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.stream.Measure 17 offset=32.0>, <music21.note.Note F#>,
#          <music21.note.Rest dotted-eighth>,
#          <music21.stream.Measure 18 offset=34.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 19 offset=36.0>, <music21.note.Note F#>,
#          <music21.note.Rest 1/3ql>, <music21.note.Note F#>,
#          <music21.note.Rest eighth>,
#          <music21.stream.Measure 20 offset=38.0>, <music21.note.Note F>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Note F>, <music21.note.Rest 11/12ql>,
#          <music21.stream.Measure 21 offset=40.0>, <music21.note.Note F>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Note F>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note C#>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note E->, <music21.stream.Measure 22 offset=42.0>,
#          <music21.note.Note E->, <music21.note.Rest dotted-eighth>,
#          <music21.note.Note E->, <music21.note.Note F>,
#          <music21.stream.Measure 23 offset=44.0>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 1/3ql>,
#          <music21.stream.Measure 24 offset=46.0>, <music21.note.Note F>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Note F>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note E->, <music21.note.Rest 1/6ql>,
#          <music21.note.Note C#>, <music21.stream.Measure 25 offset=48.0>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.stream.Measure 26 offset=50.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 27 offset=52.0>, <music21.note.Note F#>,
#          <music21.note.Rest eighth>, <music21.note.Note F#>,
#          <music21.note.Rest 1/3ql>,
#          <music21.stream.Measure 28 offset=54.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Note G#>, <music21.note.Rest quarter>,
#          <music21.stream.Measure 29 offset=56.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Note G#>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note F>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note F#>, <music21.stream.Measure 30 offset=58.0>,
#          <music21.note.Note F#>, <music21.note.Rest 5/12ql>,
#          <music21.note.Note C#>, <music21.note.Note E->,
#          <music21.stream.Measure 31 offset=60.0>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Note G#>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note F#>, <music21.note.Rest 5/12ql>,
#          <music21.stream.Measure 32 offset=62.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Note G#>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note F#>, <music21.note.Rest 5/12ql>,
#          <music21.stream.Measure 33 offset=64.0>, <music21.note.Note F#>,
#          <music21.note.Rest 1/3ql>,
#          <music21.stream.Measure 34 offset=66.0>,
#          <music21.note.Rest quarter>, <music21.note.Note C#>,
#          <music21.note.Rest 1/12ql>, <music21.note.Note E->,
#          <music21.note.Note F#>, <music21.note.Note G#>,
#          <music21.stream.Measure 35 offset=68.0>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.stream.Measure 36 offset=70.0>, <music21.note.Note G#>,
#          <music21.note.Rest quarter>,
#          <music21.stream.Measure 37 offset=72.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note F>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.stream.Measure 38 offset=74.0>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 1/12ql>, <music21.note.Note E->,
#          <music21.note.Note F#>, <music21.note.Note G#>,
#          <music21.stream.Measure 39 offset=76.0>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.stream.Measure 40 offset=78.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.stream.Measure 41 offset=80.0>, <music21.note.Note B->,
#          <music21.note.Rest dotted-eighth>,
#          <music21.stream.Measure 42 offset=82.0>,
#          <music21.note.Rest quarter>, <music21.note.Note C#>,
#          <music21.note.Rest 1/12ql>, <music21.note.Note E->,
#          <music21.note.Note F#>, <music21.note.Note G#>,
#          <music21.stream.Measure 43 offset=84.0>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.stream.Measure 44 offset=86.0>, <music21.note.Note G#>,
#          <music21.note.Rest quarter>,
#          <music21.stream.Measure 45 offset=88.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note F>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.stream.Measure 46 offset=90.0>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 1/12ql>, <music21.note.Note E->,
#          <music21.note.Note F#>, <music21.note.Note G#>,
#          <music21.stream.Measure 47 offset=92.0>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.stream.Measure 48 offset=94.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.stream.Measure 49 offset=96.0>, <music21.note.Note F#>,
#          <music21.note.Rest dotted-eighth>,
#          <music21.stream.Measure 50 offset=98.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 51 offset=100.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 52 offset=102.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 53 offset=104.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 54 offset=106.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 55 offset=108.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 56 offset=110.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 57 offset=112.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 58 offset=114.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 59 offset=116.0>, <music21.note.Note F#>,
#          <music21.note.Rest 1/3ql>, <music21.note.Note F#>,
#          <music21.note.Rest eighth>,
#          <music21.stream.Measure 60 offset=118.0>, <music21.note.Note F>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Note F>, <music21.note.Rest 11/12ql>,
#          <music21.stream.Measure 61 offset=120.0>, <music21.note.Note F>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Note F>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note C#>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note E->, <music21.stream.Measure 62 offset=122.0>,
#          <music21.note.Note E->, <music21.note.Rest dotted-eighth>,
#          <music21.note.Note E->, <music21.note.Note F>,
#          <music21.stream.Measure 63 offset=124.0>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 1/3ql>,
#          <music21.stream.Measure 64 offset=126.0>, <music21.note.Note F>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Note F>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note E->, <music21.note.Rest 1/6ql>,
#          <music21.note.Note C#>, <music21.stream.Measure 65 offset=128.0>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.stream.Measure 66 offset=130.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 67 offset=132.0>, <music21.note.Note F#>,
#          <music21.note.Rest eighth>, <music21.note.Note F#>,
#          <music21.note.Rest 1/3ql>,
#          <music21.stream.Measure 68 offset=134.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Note G#>, <music21.note.Rest quarter>,
#          <music21.stream.Measure 69 offset=136.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Note G#>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note F>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note F#>, <music21.stream.Measure 70 offset=138.0>,
#          <music21.note.Note F#>, <music21.note.Rest 5/12ql>,
#          <music21.note.Note C#>, <music21.note.Note E->,
#          <music21.stream.Measure 71 offset=140.0>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Note G#>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note F#>, <music21.note.Rest 5/12ql>,
#          <music21.stream.Measure 72 offset=142.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Note G#>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note F#>, <music21.note.Rest 5/12ql>,
#          <music21.stream.Measure 73 offset=144.0>, <music21.note.Note F#>,
#          <music21.note.Rest 1/3ql>,
#          <music21.stream.Measure 74 offset=146.0>,
#          <music21.note.Rest quarter>, <music21.note.Note C#>,
#          <music21.note.Rest 1/12ql>, <music21.note.Note E->,
#          <music21.note.Note F#>, <music21.note.Note G#>,
#          <music21.stream.Measure 75 offset=148.0>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.stream.Measure 76 offset=150.0>, <music21.note.Note G#>,
#          <music21.note.Rest quarter>,
#          <music21.stream.Measure 77 offset=152.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note F>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.stream.Measure 78 offset=154.0>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 1/12ql>, <music21.note.Note E->,
#          <music21.note.Note F#>, <music21.note.Note G#>,
#          <music21.stream.Measure 79 offset=156.0>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.stream.Measure 80 offset=158.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.stream.Measure 81 offset=160.0>, <music21.note.Note B->,
#          <music21.note.Rest dotted-eighth>,
#          <music21.stream.Measure 82 offset=162.0>,
#          <music21.note.Rest quarter>, <music21.note.Note C#>,
#          <music21.note.Rest 1/12ql>, <music21.note.Note E->,
#          <music21.note.Note F#>, <music21.note.Note G#>,
#          <music21.stream.Measure 83 offset=164.0>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.stream.Measure 84 offset=166.0>, <music21.note.Note G#>,
#          <music21.note.Rest quarter>,
#          <music21.stream.Measure 85 offset=168.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note F>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.stream.Measure 86 offset=170.0>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 1/12ql>, <music21.note.Note E->,
#          <music21.note.Note F#>, <music21.note.Note G#>,
#          <music21.stream.Measure 87 offset=172.0>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.stream.Measure 88 offset=174.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.stream.Measure 89 offset=176.0>, <music21.note.Note F#>,
#          <music21.note.Rest dotted-eighth>,
#          <music21.stream.Measure 90 offset=178.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 91 offset=180.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 92 offset=182.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 93 offset=184.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 94 offset=186.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 95 offset=188.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 96 offset=190.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 97 offset=192.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 98 offset=194.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 99 offset=196.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 100 offset=198.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 101 offset=200.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 102 offset=202.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 103 offset=204.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 104 offset=206.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 105 offset=208.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 106 offset=210.0>,
#          <music21.note.Rest quarter>, <music21.note.Note C#>,
#          <music21.note.Rest 1/12ql>, <music21.note.Note E->,
#          <music21.note.Note F#>, <music21.note.Note G#>,
#          <music21.stream.Measure 107 offset=212.0>,
#          <music21.note.Note B->, <music21.note.Rest 16th>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note E->, <music21.note.Rest 16th>,
#          <music21.note.Note G#>,
#          <music21.stream.Measure 108 offset=214.0>,
#          <music21.note.Note G#>, <music21.note.Rest quarter>,
#          <music21.stream.Measure 109 offset=216.0>,
#          <music21.note.Note G#>, <music21.note.Rest 16th>,
#          <music21.note.Note F>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.note.Note F#>,
#          <music21.stream.Measure 110 offset=218.0>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Rest 1/12ql>,
#          <music21.note.Note E->, <music21.note.Note F#>,
#          <music21.note.Note G#>,
#          <music21.stream.Measure 111 offset=220.0>,
#          <music21.note.Note B->, <music21.note.Rest 16th>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note E->, <music21.note.Rest 16th>,
#          <music21.note.Note G#>,
#          <music21.stream.Measure 112 offset=222.0>,
#          <music21.note.Note G#>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.note.Note G#>, <music21.note.Rest 16th>,
#          <music21.note.Note B->,
#          <music21.stream.Measure 113 offset=224.0>,
#          <music21.note.Note B->, <music21.note.Rest dotted-eighth>,
#          <music21.stream.Measure 114 offset=226.0>,
#          <music21.note.Rest quarter>, <music21.note.Note C#>,
#          <music21.note.Rest 1/12ql>, <music21.note.Note E->,
#          <music21.note.Note F#>, <music21.note.Note G#>,
#          <music21.stream.Measure 115 offset=228.0>,
#          <music21.note.Note B->, <music21.note.Rest 16th>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note E->, <music21.note.Rest 16th>,
#          <music21.note.Note G#>,
#          <music21.stream.Measure 116 offset=230.0>,
#          <music21.note.Note G#>, <music21.note.Rest quarter>,
#          <music21.stream.Measure 117 offset=232.0>,
#          <music21.note.Note G#>, <music21.note.Rest 16th>,
#          <music21.note.Note F>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.note.Note F#>,
#          <music21.stream.Measure 118 offset=234.0>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Rest 1/12ql>,
#          <music21.note.Note E->, <music21.note.Note F#>,
#          <music21.note.Note G#>,
#          <music21.stream.Measure 119 offset=236.0>,
#          <music21.note.Note B->, <music21.note.Rest 16th>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note E->, <music21.note.Rest 16th>,
#          <music21.note.Note G#>,
#          <music21.stream.Measure 120 offset=238.0>,
#          <music21.note.Note G#>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.note.Note G#>, <music21.note.Rest 16th>,
#          <music21.note.Note F#>,
#          <music21.stream.Measure 121 offset=240.0>,
#          <music21.note.Note F#>, <music21.note.Rest dotted-eighth>,
#          <music21.stream.Measure 122 offset=242.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 123 offset=244.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 124 offset=246.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 125 offset=248.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 126 offset=250.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 127 offset=252.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 128 offset=254.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 129 offset=256.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 130 offset=258.0>,
#          <music21.note.Rest quarter>, <music21.note.Note C#>,
#          <music21.note.Rest 1/12ql>, <music21.note.Note E->,
#          <music21.note.Note F#>, <music21.note.Note G#>,
#          <music21.stream.Measure 131 offset=260.0>,
#          <music21.note.Note B->, <music21.note.Rest 16th>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note E->, <music21.note.Rest 16th>,
#          <music21.note.Note G#>,
#          <music21.stream.Measure 132 offset=262.0>,
#          <music21.note.Note G#>, <music21.note.Rest quarter>,
#          <music21.stream.Measure 133 offset=264.0>,
#          <music21.note.Note G#>, <music21.note.Rest 16th>,
#          <music21.note.Note F>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.note.Note F#>,
#          <music21.stream.Measure 134 offset=266.0>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Rest 1/12ql>,
#          <music21.note.Note E->, <music21.note.Note F#>,
#          <music21.note.Note G#>,
#          <music21.stream.Measure 135 offset=268.0>,
#          <music21.note.Note B->, <music21.note.Rest 16th>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note E->, <music21.note.Rest 16th>,
#          <music21.note.Note G#>,
#          <music21.stream.Measure 136 offset=270.0>,
#          <music21.note.Note G#>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.note.Note G#>, <music21.note.Rest 16th>,
#          <music21.note.Note F#>,
#          <music21.stream.Measure 137 offset=272.0>,
#          <music21.note.Note F#>, <music21.note.Rest dotted-eighth>,
#          <music21.bar.Barline type=final>]], dtype=object),
#  array([[<music21.stream.Measure 1 offset=0.0>,
#          <music21.instrument.Piano 'MELODY: Piano'>,
#          <music21.clef.TrebleClef>,
#          <music21.tempo.MetronomeMark larghetto Quarter=62.0>,
#          <music21.meter.TimeSignature 2/4>, <music21.note.Rest half>,
#          <music21.stream.Measure 2 offset=2.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 3 offset=4.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 4 offset=6.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 5 offset=8.0>, <music21.note.Rest 4/3ql>,
#          <music21.tempo.MetronomeMark adagio Quarter=58.0>,
#          <music21.note.Rest 1/3ql>,
#          <music21.tempo.MetronomeMark lento Quarter=52.0>,
#          <music21.note.Rest 1/3ql>,
#          <music21.stream.Measure 6 offset=10.0>,
#          <music21.tempo.MetronomeMark largo Quarter=47.0>,
#          <music21.note.Rest 16th>,
#          <music21.tempo.MetronomeMark lento Quarter=50.0>,
#          <music21.note.Rest 1/12ql>,
#          <music21.tempo.MetronomeMark largo Quarter=45.0>,
#          <music21.note.Rest 1/6ql>,
#          <music21.tempo.MetronomeMark largo Quarter=47.0>,
#          <music21.note.Rest 1/6ql>,
#          <music21.tempo.MetronomeMark largo Quarter=46.0>,
#          <music21.note.Rest 1/3ql>,
#          <music21.tempo.MetronomeMark larghetto Quarter=62.0>,
#          <music21.note.Rest quarter>,
#          <music21.stream.Measure 7 offset=12.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 8 offset=14.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 9 offset=16.0>,
#          <music21.note.Rest 1.25ql>,
#          <music21.tempo.MetronomeMark larghetto Quarter=59.0>,
#          <music21.note.Rest 1/12ql>,
#          <music21.tempo.MetronomeMark adagio Quarter=56.0>,
#          <music21.note.Rest 2/3ql>,
#          <music21.stream.Measure 10 offset=18.0>,
#          <music21.note.Rest 4/3ql>,
#          <music21.tempo.MetronomeMark larghetto Quarter=62.0>,
#          <music21.note.Rest 2/3ql>,
#          <music21.stream.Measure 11 offset=20.0>,
#          <music21.note.Rest eighth>,
#          <music21.tempo.MetronomeMark adagietto Quarter=64.0>,
#          <music21.note.Note E->, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.stream.Measure 12 offset=22.0>,
#          <music21.note.Note B>, <music21.note.Rest 16th>,
#          <music21.note.Note B->, <music21.note.Rest 16th>,
#          <music21.note.Note B>, <music21.note.Note C#>,
#          <music21.note.Rest 1/12ql>,
#          <music21.stream.Measure 13 offset=24.0>,
#          <music21.note.Rest eighth>, <music21.note.Note B>,
#          <music21.note.Note B->, <music21.note.Note B>,
#          <music21.note.Note B->, <music21.note.Note B>,
#          <music21.stream.Measure 14 offset=26.0>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Note B->, <music21.stream.Measure 15 offset=28.0>,
#          <music21.note.Note B->, <music21.note.Rest 16th>,
#          <music21.note.Note E->, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.note.Rest 16th>,
#          <music21.stream.Measure 16 offset=30.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.stream.Measure 17 offset=32.0>, <music21.note.Note C#>,
#          <music21.note.Note B>, <music21.note.Rest 16th>,
#          <music21.note.Note B->, <music21.note.Note B>,
#          <music21.stream.Measure 18 offset=34.0>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.note.Note B>, <music21.note.Note C#>,
#          <music21.stream.Measure 19 offset=36.0>, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.note.Rest 16th>,
#          <music21.stream.Measure 20 offset=38.0>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note B>,
#          <music21.note.Note C#>, <music21.stream.Measure 21 offset=40.0>,
#          <music21.note.Rest eighth>, <music21.note.Note B>,
#          <music21.note.Note B->, <music21.note.Note B>,
#          <music21.note.Note B->, <music21.note.Note B>,
#          <music21.stream.Measure 22 offset=42.0>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Note B->, <music21.stream.Measure 23 offset=44.0>,
#          <music21.note.Note B->, <music21.note.Rest 16th>,
#          <music21.note.Note E->, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.note.Rest 16th>,
#          <music21.stream.Measure 24 offset=46.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.stream.Measure 25 offset=48.0>,
#          <music21.note.Rest eighth>, <music21.note.Note E>,
#          <music21.note.Note E->, <music21.note.Note E>,
#          <music21.note.Note E->, <music21.note.Note E>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 26 offset=50.0>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 27 offset=52.0>, <music21.note.Note F#>,
#          <music21.note.Note E>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.stream.Measure 28 offset=54.0>,
#          <music21.note.Rest eighth>, <music21.note.Note C#>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.stream.Measure 29 offset=56.0>, <music21.note.Note E->,
#          <music21.note.Note C#>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 30 offset=58.0>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.stream.Measure 31 offset=60.0>,
#          <music21.note.Rest eighth>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note E>,
#          <music21.note.Note E>, <music21.note.Note E>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 32 offset=62.0>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note E>,
#          <music21.note.Rest eighth>,
#          <music21.stream.Measure 33 offset=64.0>, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.note.Note E>,
#          <music21.note.Rest 16th>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 34 offset=66.0>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.stream.Measure 35 offset=68.0>, <music21.note.Note F#>,
#          <music21.note.Note E>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.stream.Measure 36 offset=70.0>,
#          <music21.note.Rest eighth>, <music21.note.Note C#>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note B->, <music21.note.Rest 16th>,
#          <music21.stream.Measure 37 offset=72.0>, <music21.note.Note G#>,
#          <music21.note.Note B->, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 38 offset=74.0>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Note B->, <music21.note.Note F#>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 39 offset=76.0>,
#          <music21.note.Rest eighth>, <music21.note.Note E>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 40 offset=78.0>, <music21.note.Note B>,
#          <music21.note.Note F#>, <music21.note.Rest eighth>,
#          <music21.stream.Measure 41 offset=80.0>, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.note.Note E>,
#          <music21.note.Rest 16th>, <music21.note.Note E>,
#          <music21.note.Note E->, <music21.note.Note E>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 42 offset=82.0>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.stream.Measure 43 offset=84.0>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>, <music21.note.Note B>,
#          <music21.stream.Measure 44 offset=86.0>, <music21.note.Note B>,
#          <music21.tempo.MetronomeMark larghetto Quarter=61.0>,
#          <music21.tempo.MetronomeMark adagietto Quarter=64.0>,
#          <music21.note.Rest dotted-eighth>,
#          <music21.stream.Measure 45 offset=88.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 46 offset=90.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 47 offset=92.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 48 offset=94.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 49 offset=96.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 50 offset=98.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 51 offset=100.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 52 offset=102.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 53 offset=104.0>,
#          <music21.note.Rest eighth>, <music21.note.Note E->,
#          <music21.note.Note C#>, <music21.note.Note E->,
#          <music21.note.Note C#>, <music21.note.Note E->,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 54 offset=106.0>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note B>,
#          <music21.note.Note C#>, <music21.stream.Measure 55 offset=108.0>,
#          <music21.note.Rest eighth>, <music21.note.Note B>,
#          <music21.note.Note B->, <music21.note.Note B>,
#          <music21.note.Note B->, <music21.note.Note B>,
#          <music21.stream.Measure 56 offset=110.0>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Note B->, <music21.stream.Measure 57 offset=112.0>,
#          <music21.note.Note B->, <music21.note.Rest 16th>,
#          <music21.note.Note E->, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.note.Rest 16th>,
#          <music21.stream.Measure 58 offset=114.0>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.stream.Measure 59 offset=116.0>,
#          <music21.note.Rest eighth>, <music21.note.Note E>,
#          <music21.note.Note E->, <music21.note.Note E>,
#          <music21.note.Note E->, <music21.note.Note E>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 60 offset=118.0>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 61 offset=120.0>, <music21.note.Note F#>,
#          <music21.note.Note E>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.stream.Measure 62 offset=122.0>,
#          <music21.note.Rest eighth>, <music21.note.Note C#>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.stream.Measure 63 offset=124.0>, <music21.note.Note E->,
#          <music21.note.Note C#>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 64 offset=126.0>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.stream.Measure 65 offset=128.0>,
#          <music21.note.Rest eighth>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note E>,
#          <music21.note.Note E>, <music21.note.Note E>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 66 offset=130.0>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note E>,
#          <music21.note.Rest eighth>,
#          <music21.stream.Measure 67 offset=132.0>, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.note.Note E>,
#          <music21.note.Rest 16th>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 68 offset=134.0>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.stream.Measure 69 offset=136.0>, <music21.note.Note F#>,
#          <music21.note.Note E>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.stream.Measure 70 offset=138.0>,
#          <music21.note.Rest eighth>, <music21.note.Note C#>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note B->, <music21.note.Rest 16th>,
#          <music21.stream.Measure 71 offset=140.0>, <music21.note.Note G#>,
#          <music21.note.Note B->, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 72 offset=142.0>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Note B->, <music21.note.Note F#>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 73 offset=144.0>,
#          <music21.note.Rest eighth>, <music21.note.Note E>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 74 offset=146.0>, <music21.note.Note B>,
#          <music21.note.Note F#>, <music21.note.Rest eighth>,
#          <music21.stream.Measure 75 offset=148.0>, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.note.Note E>,
#          <music21.note.Rest 16th>, <music21.note.Note E>,
#          <music21.note.Note E->, <music21.note.Note E>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 76 offset=150.0>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.stream.Measure 77 offset=152.0>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note B>,
#          <music21.stream.Measure 78 offset=154.0>, <music21.note.Note B>,
#          <music21.stream.Measure 79 offset=156.0>, <music21.note.Note B>,
#          <music21.note.Rest 1.75ql>,
#          <music21.stream.Measure 80 offset=158.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 81 offset=160.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 82 offset=162.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 83 offset=164.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 84 offset=166.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 85 offset=168.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 86 offset=170.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 87 offset=172.0>,
#          <music21.note.Rest eighth>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.stream.Measure 88 offset=174.0>,
#          <music21.note.Rest eighth>, <music21.note.Note C#>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.stream.Measure 89 offset=176.0>, <music21.note.Note E->,
#          <music21.note.Note C#>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 90 offset=178.0>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.stream.Measure 91 offset=180.0>,
#          <music21.note.Rest eighth>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note E>,
#          <music21.note.Note E>, <music21.note.Note E>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 92 offset=182.0>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note E>,
#          <music21.note.Rest eighth>,
#          <music21.stream.Measure 93 offset=184.0>, <music21.note.Note C#>,
#          <music21.note.Note E->, <music21.note.Note E>,
#          <music21.note.Rest 16th>, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 94 offset=186.0>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.stream.Measure 95 offset=188.0>, <music21.note.Note F#>,
#          <music21.note.Note E>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note E->,
#          <music21.stream.Measure 96 offset=190.0>,
#          <music21.note.Rest eighth>, <music21.note.Note C#>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note B->, <music21.note.Rest 16th>,
#          <music21.stream.Measure 97 offset=192.0>, <music21.note.Note G#>,
#          <music21.note.Note B->, <music21.note.Note B>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Rest 16th>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 98 offset=194.0>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Note B->, <music21.note.Note F#>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 99 offset=196.0>,
#          <music21.note.Rest eighth>, <music21.note.Note E>,
#          <music21.note.Rest 16th>, <music21.note.Note C#>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 100 offset=198.0>, <music21.note.Note B>,
#          <music21.note.Note F#>, <music21.note.Rest eighth>,
#          <music21.stream.Measure 101 offset=200.0>,
#          <music21.note.Note C#>, <music21.note.Note E->,
#          <music21.note.Note E>, <music21.note.Rest 16th>,
#          <music21.note.Note E>, <music21.note.Note E->,
#          <music21.note.Note E>, <music21.note.Rest 16th>,
#          <music21.stream.Measure 102 offset=202.0>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note G#>, <music21.note.Rest 16th>,
#          <music21.note.Note B->,
#          <music21.stream.Measure 103 offset=204.0>,
#          <music21.note.Note B->, <music21.note.Rest 16th>,
#          <music21.note.Note B>, <music21.stream.Measure 104 offset=206.0>,
#          <music21.note.Note B>, <music21.note.Rest 16th>,
#          <music21.stream.Measure 105 offset=208.0>,
#          <music21.note.Note C#>, <music21.note.Note E->,
#          <music21.note.Note E>, <music21.note.Rest 16th>,
#          <music21.note.Note E>, <music21.note.Note E->,
#          <music21.note.Note E>, <music21.note.Rest 16th>,
#          <music21.stream.Measure 106 offset=210.0>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note E->, <music21.note.Rest 16th>,
#          <music21.note.Note C#>,
#          <music21.stream.Measure 107 offset=212.0>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.note.Note B>, <music21.stream.Measure 108 offset=214.0>,
#          <music21.note.Note B>, <music21.note.Rest 16th>,
#          <music21.stream.Measure 109 offset=216.0>,
#          <music21.chord.Chord C#5 E-5>, <music21.note.Rest 16th>,
#          <music21.note.Note E>, <music21.note.Rest 16th>,
#          <music21.note.Note E>, <music21.note.Note E->,
#          <music21.note.Rest 1/12ql>, <music21.note.Note E>,
#          <music21.stream.Measure 110 offset=218.0>,
#          <music21.stream.Voice 0x1b33f9b7a30>, <music21.note.Rest 16th>,
#          <music21.note.Note F#>, <music21.note.Rest quarter>,
#          <music21.stream.Voice 0x1b33f817640>,
#          <music21.note.Rest dotted-eighth>, <music21.note.Note G#>,
#          <music21.stream.Measure 111 offset=220.0>,
#          <music21.note.Note B->, <music21.note.Note B>,
#          <music21.tempo.MetronomeMark adagio Quarter=57.0>,
#          <music21.stream.Measure 112 offset=222.0>, <music21.note.Note B>,
#          <music21.stream.Measure 113 offset=224.0>, <music21.note.Note B>,
#          <music21.note.Rest eighth>, <music21.bar.Barline type=final>]],
#        dtype=object),
#  array([[<music21.stream.Measure 1 offset=0.0>,
#          <music21.instrument.Piano 'MELODY: Piano'>,
#          <music21.clef.TrebleClef>,
#          <music21.tempo.MetronomeMark andantino Quarter=82.0>,
#          <music21.meter.TimeSignature 2/4>, <music21.note.Rest half>,
#          <music21.stream.Measure 2 offset=2.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 3 offset=4.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 4 offset=6.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 5 offset=8.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 6 offset=10.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 7 offset=12.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 8 offset=14.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 9 offset=16.0>, <music21.note.Rest half>,
#          <music21.stream.Measure 10 offset=18.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 11 offset=20.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 12 offset=22.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 13 offset=24.0>,
#          <music21.note.Rest half>,
#          <music21.stream.Measure 14 offset=26.0>,
# ...
#          <music21.note.Rest dotted-quarter>, <music21.note.Note G#>,
#          <music21.stream.Measure 64 offset=252.0>,
#          <music21.stream.Voice 0x1b365caeb50>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note C#>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note C#>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note C#>, <music21.note.Note B>,
#          <music21.note.Rest 11/12ql>, <music21.note.Note B->,
#          <music21.stream.Voice 0x1b365cae3a0>, <music21.note.Rest 2.75ql>,
#          <music21.note.Note G#>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.stream.Measure 65 offset=256.0>,
#          <music21.note.Note B->, <music21.note.Rest 11/12ql>,
#          <music21.note.Note G#>, <music21.stream.Measure 66 offset=260.0>,
#          <music21.stream.Voice 0x1b35f2003d0>,
#          <music21.note.Rest dotted-eighth>, <music21.note.Note E->,
#          <music21.note.Rest 7/12ql>, <music21.note.Note C#>,
#          <music21.note.Rest 1/6ql>, <music21.stream.Voice 0x1b35f200820>,
#          <music21.note.Rest 3.75ql>, <music21.note.Note E->,
#          <music21.note.Note G#>, <music21.stream.Measure 67 offset=264.0>,
#          <music21.stream.Voice 0x1b35f200d60>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note C#>, <music21.note.Rest 35/12ql>,
#          <music21.note.Note B>, <music21.stream.Voice 0x1b35c58ad00>,
#          <music21.note.Rest dotted-eighth>, <music21.note.Note B>,
#          <music21.note.Rest dotted-quarter>, <music21.note.Note E->,
#          <music21.stream.Measure 68 offset=268.0>,
#          <music21.stream.Voice 0x1b35cb71f40>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note B>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note B>, <music21.note.Rest 11/12ql>,
#          <music21.note.Note G#>, <music21.note.Rest 2/3ql>,
#          <music21.note.Note G#>, <music21.stream.Voice 0x1b35cb71e50>,
#          <music21.note.Rest 4/3ql>, <music21.note.Note B->,
#          <music21.note.Rest 5/12ql>, <music21.note.Note F#>,
#          <music21.note.Rest 16th>,
#          <music21.stream.Measure 69 offset=272.0>, <music21.note.Note G#>,
#          <music21.note.Rest 11/12ql>, <music21.note.Note G#>,
#          <music21.stream.Measure 70 offset=276.0>,
#          <music21.stream.Voice 0x1b363c4eaf0>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note G#>, <music21.note.Rest eighth>,
#          <music21.note.Note F#>, <music21.note.Rest 1/6ql>,
#          <music21.stream.Voice 0x1b361c0bd90>, <music21.note.Rest 3.75ql>,
#          <music21.note.Note G#>, <music21.note.Note G#>,
#          <music21.stream.Measure 71 offset=280.0>,
#          <music21.stream.Voice 0x1b35f1910a0>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note F#>, <music21.note.Rest 35/12ql>,
#          <music21.note.Note G#>, <music21.stream.Voice 0x1b36b2b7ac0>,
#          <music21.note.Rest dotted-eighth>, <music21.note.Note E->,
#          <music21.note.Rest 23/12ql>, <music21.note.Note G#>,
#          <music21.stream.Measure 72 offset=284.0>,
#          <music21.note.Rest 1/3ql>, <music21.note.Note G#>,
#          <music21.note.Rest 1/6ql>, <music21.note.Note G#>,
#          <music21.note.Rest 16th>, <music21.note.Note B->,
#          <music21.note.Note G#>, <music21.note.Note F#>,
#          <music21.stream.Measure 73 offset=288.0>, <music21.note.Note F#>,
#          <music21.note.Note G#>, <music21.stream.Measure 74 offset=292.0>,
#          <music21.note.Note G#>, <music21.stream.Measure 75 offset=296.0>,
#          <music21.note.Note G#>, <music21.note.Rest 17/6ql>,
#          <music21.note.Note G#>, <music21.stream.Measure 76 offset=300.0>,
#          <music21.stream.Voice 0x1b36340f490>, <music21.note.Note F#>,
#          <music21.note.Note G#>, <music21.note.Note E->,
#          <music21.note.Rest 1/6ql>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Note F#>, <music21.note.Note G#>,
#          <music21.note.Rest eighth>, <music21.note.Note F#>,
#          <music21.stream.Voice 0x1b36793c0d0>, <music21.note.Rest 2.75ql>,
#          <music21.note.Note B>, <music21.note.Rest 11/12ql>,
#          <music21.stream.Measure 77 offset=304.0>,
#          <music21.stream.Voice 0x1b36793c460>, <music21.note.Note E->,
#          <music21.note.Note F#>, <music21.note.Rest eighth>,
#          <music21.note.Note F#>, <music21.note.Rest 2/3ql>,
#          <music21.note.Note C#>, <music21.stream.Voice 0x1b36793c8e0>,
#          <music21.note.Rest dotted-eighth>, <music21.note.Note G#>,
#          <music21.note.Rest 31/12ql>,
#          <music21.stream.Measure 78 offset=308.0>,
#          <music21.stream.Voice 0x1b36793cb50>, <music21.note.Note B>,
#          <music21.note.Note G#>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note G#>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Rest eighth>,
#          <music21.note.Note B>, <music21.stream.Voice 0x1b351307bb0>,
#          <music21.note.Rest half>, <music21.note.Note B>,
#          <music21.note.Rest 5/12ql>, <music21.note.Note E->,
#          <music21.note.Rest 7/12ql>,
#          <music21.stream.Measure 79 offset=312.0>,
#          <music21.stream.Voice 0x1b3513074c0>, <music21.note.Note G#>,
#          <music21.note.Note B>, <music21.note.Rest eighth>,
#          <music21.note.Note F#>, <music21.note.Rest dotted-eighth>,
#          <music21.note.Note G#>, <music21.note.Rest 1/6ql>,
#          <music21.stream.Voice 0x1b361a60b20>,
#          <music21.note.Rest dotted-eighth>, <music21.note.Note G#>,
#          <music21.note.Rest 8/3ql>, <music21.note.Note F#>,
#          <music21.stream.Measure 80 offset=316.0>,
#          <music21.stream.Voice 0x1b35876d580>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note E->, <music21.note.Rest 1/6ql>,
#          <music21.note.Note E->, <music21.note.Rest 16th>,
#          <music21.note.Note G#>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note F#>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note G#>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note G#>, <music21.note.Rest 16th>,
#          <music21.note.Note B>, <music21.note.Rest 1/6ql>,
#          <music21.stream.Voice 0x1b367ded1f0>, <music21.note.Rest 3.75ql>,
#          <music21.note.Note G#>, <music21.note.Note F#>,
#          <music21.stream.Measure 81 offset=320.0>,
#          <music21.stream.Voice 0x1b367ded610>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note F#>, <music21.note.Rest eighth>,
#          <music21.note.Note B>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note G#>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note B>, <music21.note.Rest 11/12ql>,
#          <music21.note.Note B>, <music21.stream.Voice 0x1b365b6b370>,
#          <music21.note.Rest dotted-eighth>, <music21.note.Note F#>,
#          <music21.note.Rest 5/3ql>, <music21.note.Note B>,
#          <music21.note.Rest dotted-eighth>, <music21.note.Note G#>,
#          <music21.stream.Measure 82 offset=324.0>,
#          <music21.stream.Voice 0x1b365b6b520>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note B>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note B>, <music21.note.Rest 16th>,
#          <music21.note.Note B->, <music21.note.Note G#>,
#          <music21.note.Rest 11/12ql>, <music21.note.Note G#>,
#          <music21.stream.Voice 0x1b366f38100>, <music21.note.Rest 2.75ql>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.stream.Measure 83 offset=328.0>, <music21.note.Note G#>,
#          <music21.note.Rest 11/12ql>, <music21.note.Note G#>,
#          <music21.stream.Measure 84 offset=332.0>,
#          <music21.stream.Voice 0x1b3580d6b20>, <music21.note.Note F#>,
#          <music21.note.Note E->, <music21.note.Rest 1/6ql>,
#          <music21.note.Note E->, <music21.note.Rest 16th>,
#          <music21.note.Note G#>, <music21.note.Note F#>,
#          <music21.note.Note G#>, <music21.note.Rest eighth>,
#          <music21.note.Note F#>, <music21.stream.Voice 0x1b36a715d90>,
#          <music21.note.Rest 2.75ql>, <music21.note.Note B>,
#          <music21.note.Rest 7/12ql>, <music21.note.Note G#>,
#          <music21.stream.Measure 85 offset=336.0>,
#          <music21.stream.Voice 0x1b36a715640>, <music21.note.Note E->,
#          <music21.note.Note F#>, <music21.note.Rest eighth>,
#          <music21.note.Note F#>, <music21.note.Rest eighth>,
#          <music21.note.Note C#>, <music21.stream.Voice 0x1b36a715880>,
#          <music21.note.Rest dotted-eighth>, <music21.note.Note G#>,
#          <music21.note.Rest 31/12ql>, <music21.note.Note F#>,
#          <music21.stream.Measure 86 offset=340.0>,
#          <music21.stream.Voice 0x1b36a715250>, <music21.note.Note B>,
#          <music21.note.Note G#>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note G#>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Note B>,
#          <music21.note.Note C#>, <music21.note.Rest eighth>,
#          <music21.note.Note B>, <music21.stream.Voice 0x1b367ff53a0>,
#          <music21.note.Rest 2.75ql>, <music21.note.Note E->,
#          <music21.note.Rest 7/12ql>, <music21.note.Note C#>,
#          <music21.stream.Measure 87 offset=344.0>,
#          <music21.stream.Voice 0x1b367d68cd0>, <music21.note.Note G#>,
#          <music21.note.Note B>, <music21.note.Rest eighth>,
#          <music21.note.Note F#>, <music21.note.Rest eighth>,
#          <music21.note.Note G#>, <music21.note.Rest 1/6ql>,
#          <music21.stream.Voice 0x1b363621d00>,
#          <music21.note.Rest dotted-eighth>, <music21.note.Note G#>,
#          <music21.note.Rest 8/3ql>, <music21.note.Note F#>,
#          <music21.note.Note B>, <music21.stream.Measure 88 offset=348.0>,
#          <music21.stream.Voice 0x1b363621f70>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note E->, <music21.note.Rest eighth>,
#          <music21.note.Note G#>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note G#>, <music21.note.Note G#>,
#          <music21.note.Rest 1/3ql>, <music21.note.Note G#>,
#          <music21.stream.Voice 0x1b353c0fe80>,
#          <music21.note.Rest dotted-eighth>, <music21.note.Note E->,
#          <music21.note.Rest 2.25ql>, <music21.note.Note B>,
#          <music21.note.Rest 1/6ql>, <music21.note.Note F#>,
#          <music21.stream.Measure 89 offset=352.0>,
#          <music21.stream.Voice 0x1b353c19eb0>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note F#>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note F#>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note G#>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note B>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note B>, <music21.note.Rest eighth>,
#          <music21.note.Note B>, <music21.stream.Voice 0x1b3577f4f40>,
#          <music21.note.Rest 4/3ql>, <music21.note.Note B>,
#          <music21.note.Rest 29/12ql>, <music21.note.Note G#>,
#          <music21.stream.Measure 90 offset=356.0>,
#          <music21.note.Rest 1/3ql>, <music21.note.Note B>,
#          <music21.note.Rest 1/6ql>, <music21.note.Note B>,
#          <music21.note.Rest 1/3ql>, <music21.note.Note B->,
#          <music21.note.Rest eighth>, <music21.note.Note G#>,
#          <music21.note.Rest 1/6ql>, <music21.note.Note F#>,
#          <music21.note.Rest 1/3ql>, <music21.note.Note G#>,
#          <music21.stream.Measure 91 offset=360.0>, <music21.note.Note G#>,
#          <music21.note.Rest 1/3ql>, <music21.note.Note G#>,
#          <music21.stream.Measure 92 offset=364.0>,
#          <music21.stream.Voice 0x1b35c2c6d00>, <music21.note.Note F#>,
#          <music21.note.Note G#>, <music21.note.Note E->,
#          <music21.note.Rest 1/6ql>, <music21.note.Note E->,
#          <music21.note.Rest 16th>, <music21.note.Note G#>,
#          <music21.note.Note F#>, <music21.note.Note G#>,
#          <music21.note.Rest eighth>, <music21.note.Note F#>,
#          <music21.stream.Voice 0x1b36433efa0>, <music21.note.Rest 2.75ql>,
#          <music21.note.Note B>, <music21.note.Rest 7/12ql>,
#          <music21.stream.Measure 93 offset=368.0>,
#          <music21.stream.Voice 0x1b36433ed60>, <music21.note.Note E->,
#          <music21.note.Note F#>, <music21.note.Rest eighth>,
#          <music21.note.Note G#>, <music21.note.Rest dotted-quarter>,
#          <music21.note.Note C#>, <music21.stream.Voice 0x1b363a27dc0>,
#          <music21.note.Rest dotted-eighth>, <music21.note.Note G#>,
#          <music21.note.Rest 2/3ql>, <music21.note.Note F#>,
#          <music21.note.Rest 1.25ql>, <music21.note.Note F#>,
#          <music21.stream.Measure 94 offset=372.0>,
#          <music21.stream.Voice 0x1b353ca67c0>, <music21.note.Note B>,
#          <music21.note.Note G#>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note G#>, <music21.note.Rest 16th>,
#          <music21.note.Note C#>, <music21.note.Note B>,
#          <music21.note.Note C#>, <music21.note.Rest eighth>,
#          <music21.note.Note B>, <music21.stream.Voice 0x1b353ca6310>,
#          <music21.note.Rest 2.75ql>, <music21.note.Note E->,
#          <music21.note.Rest 7/12ql>, <music21.note.Note C#>,
#          <music21.stream.Measure 95 offset=376.0>,
#          <music21.stream.Voice 0x1b363282be0>, <music21.note.Note G#>,
#          <music21.note.Note B>, <music21.note.Rest eighth>,
#          <music21.note.Note F#>, <music21.note.Rest 2/3ql>,
#          <music21.note.Note G#>, <music21.note.Rest 1/6ql>,
#          <music21.stream.Voice 0x1b3632822b0>,
#          <music21.note.Rest dotted-eighth>, <music21.note.Note G#>,
#          <music21.note.Rest 8/3ql>, <music21.note.Note F#>,
#          <music21.stream.Measure 96 offset=380.0>,
#          <music21.stream.Voice 0x1b3632829d0>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note E->, <music21.note.Rest eighth>,
#          <music21.note.Note G#>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note G#>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note G#>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note G#>, <music21.stream.Voice 0x1b352e3c940>,
#          <music21.note.Rest dotted-eighth>, <music21.note.Note E->,
#          <music21.note.Rest 2.25ql>, <music21.note.Note B>,
#          <music21.note.Rest 1/6ql>, <music21.note.Note F#>,
#          <music21.stream.Measure 97 offset=384.0>,
#          <music21.stream.Voice 0x1b36650b730>, <music21.note.Rest 16th>,
#          <music21.note.Note F#>, <music21.note.Rest 16th>,
#          <music21.note.Note F#>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note G#>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note B>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note B>, <music21.note.Rest eighth>,
#          <music21.note.Note B>, <music21.stream.Voice 0x1b36650b2e0>,
#          <music21.note.Rest 4/3ql>, <music21.note.Note B>,
#          <music21.note.Rest 29/12ql>,
#          <music21.stream.Measure 98 offset=388.0>,
#          <music21.note.Rest 1/3ql>, <music21.note.Note B>,
#          <music21.note.Rest 1/6ql>, <music21.note.Note B>,
#          <music21.note.Rest 1/3ql>, <music21.note.Note B->,
#          <music21.note.Rest eighth>, <music21.note.Note G#>,
#          <music21.note.Rest 1/6ql>, <music21.note.Note F#>,
#          <music21.note.Rest 1/3ql>, <music21.note.Note G#>,
#          <music21.stream.Measure 99 offset=392.0>, <music21.note.Note G#>,
#          <music21.note.Rest dotted-eighth>, <music21.note.Note B>,
#          <music21.stream.Measure 100 offset=396.0>,
#          <music21.stream.Voice 0x1b3660fb700>, <music21.note.Rest 1/3ql>,
#          <music21.note.Note B>, <music21.note.Rest 1/6ql>,
#          <music21.note.Note B>, <music21.note.Rest 11/12ql>,
#          <music21.note.Note B->, <music21.note.Note F#>,
#          <music21.stream.Voice 0x1b3660fbb20>, <music21.note.Rest 4/3ql>,
#          <music21.note.Note C#>, <music21.note.Rest 5/3ql>,
#          <music21.stream.Measure 101 offset=400.0>,
#          <music21.note.Note F#>, <music21.note.Note G#>,
#          <music21.stream.Measure 102 offset=404.0>,
#          <music21.note.Note G#>, <music21.bar.Barline type=final>]],
#        dtype=object)]

# %%
# processing unparsed notes


notes_array = []

for notes_to_parse in unparsed_notes_array:
    for element in notes_to_parse[0]:
        # note
        if isinstance(element, note.Note):
            d = duration.Duration()
            d.quarterLength = element.quarterLength
            notes_array.append([str(element.pitch),  f"{d.type}={element.quarterLength}"])

# %%
notes_array
# Out:
# [['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', 'quarter=1.0'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'eighth=0.75'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'complex=1.25'],
#  ['F#4', 'quarter=2/3'],
#  ['F#4', 'eighth=0.5'],
#  ['F4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F4', 'eighth=1/3'],
#  ['F4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['E-4', 'eighth=0.75'],
#  ['E-4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['F#4', 'eighth=0.75'],
#  ['F#4', 'quarter=2/3'],
#  ['F4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['C#4', 'quarter=1.75'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'quarter=2/3'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F#4', 'half=13/12'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F#4', 'half=5/3'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', 'quarter=1.0'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'eighth=0.75'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', 'eighth=0.5'],
#  ['B-4', 'complex=1.25'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', 'quarter=1.0'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'eighth=0.75'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'complex=1.25'],
#  ['F#4', 'quarter=2/3'],
#  ['F#4', 'eighth=0.5'],
#  ['F4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F4', 'eighth=1/3'],
#  ['F4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['E-4', 'eighth=0.75'],
#  ['E-4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['F#4', 'eighth=0.75'],
#  ['F#4', 'quarter=2/3'],
#  ['F4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['C#4', 'quarter=1.75'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'quarter=2/3'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F#4', 'half=13/12'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F#4', 'half=5/3'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', 'quarter=1.0'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'eighth=0.75'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', 'eighth=0.5'],
#  ['B-4', 'complex=1.25'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', 'quarter=1.0'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'eighth=0.75'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'complex=1.25'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', 'quarter=1.0'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'eighth=0.75'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', 'eighth=0.5'],
#  ['B-4', 'complex=1.25'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', 'quarter=1.0'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'eighth=0.75'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'complex=1.25'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', 'quarter=1.0'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'eighth=0.75'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'complex=1.25'],
#  ['E-5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', 'eighth=0.5'],
#  ['B4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['B4', '16th=0.25'],
#  ['C#5', 'quarter=2/3'],
#  ['B4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['B4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['B4', 'eighth=0.5'],
#  ['B4', '16th=0.25'],
#  ['B4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['G#5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['C#5', 'eighth=0.5'],
#  ['C#5', 'eighth=0.5'],
#  ['B4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['B4', 'eighth=0.75'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['B4', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['C#5', 'eighth=0.5'],
#  ['E-5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['B4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['B4', '16th=0.25'],
#  ['C#5', 'eighth=0.75'],
#  ['B4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['B4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['B4', 'eighth=0.5'],
#  ['B4', '16th=0.25'],
#  ['B4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['G#5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['G#5', '16th=0.25'],
#  ['F#5', 'eighth=0.5'],
#  ['E5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['B5', '16th=0.25'],
#  ['F#5', 'complex=1.25'],
#  ['F#5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', 'eighth=0.5'],
#  ['C#5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['C#5', 'eighth=0.5'],
#  ['E-5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['B4', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['B5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['G#5', '16th=0.25'],
#  ['F#5', 'eighth=0.5'],
#  ['G#5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', 'quarter=1.0'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['B5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['G#5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['F#5', 'eighth=0.5'],
#  ['F#5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', 'eighth=0.5'],
#  ['C#5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['G#5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['B5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['G#5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['F#5', 'eighth=0.5'],
#  ['E5', 'eighth=0.75'],
#  ['C#6', '16th=0.25'],
#  ['B5', '16th=0.25'],
#  ['F#5', 'complex=1.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['E-5', 'eighth=0.75'],
#  ['C#5', 'eighth=0.5'],
#  ['C#5', '16th=0.25'],
#  ['B4', 'quarter=1.5'],
#  ['B4', 'complex=1.25'],
#  ['E-5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['B4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['B4', '16th=0.25'],
#  ['C#5', 'eighth=0.75'],
#  ['B4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['B4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['B4', 'eighth=0.5'],
#  ['B4', '16th=0.25'],
#  ['B4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['G#5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['G#5', '16th=0.25'],
#  ['F#5', 'eighth=0.5'],
#  ['E5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['B5', '16th=0.25'],
#  ['F#5', 'complex=1.25'],
#  ['F#5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', 'eighth=0.5'],
#  ['C#5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['C#5', 'eighth=0.5'],
#  ['E-5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['B4', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['B5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['G#5', '16th=0.25'],
#  ['F#5', 'eighth=0.5'],
#  ['G#5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', 'quarter=1.0'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['B5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['G#5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['F#5', 'eighth=0.5'],
#  ['F#5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', 'eighth=0.5'],
#  ['C#5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['G#5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['B5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['G#5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['F#5', 'eighth=0.5'],
#  ['E5', 'eighth=0.75'],
#  ['C#6', '16th=0.25'],
#  ['B5', '16th=0.25'],
#  ['F#5', 'complex=1.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['G#5', 'eighth=0.75'],
#  ['B-5', 'eighth=0.5'],
#  ['B-5', '16th=0.25'],
#  ['B5', 'quarter=1.5'],
#  ['B5', 'half=2.0'],
#  ['B5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', 'eighth=0.5'],
#  ['C#5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['C#5', 'eighth=0.5'],
#  ['E-5', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['B4', '16th=0.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['B5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['G#5', '16th=0.25'],
#  ['F#5', 'eighth=0.5'],
#  ['G#5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', 'quarter=1.0'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['B5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['G#5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['F#5', 'eighth=0.5'],
#  ['F#5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', 'eighth=0.5'],
#  ['C#5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['G#5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['B5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['G#5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['F#5', 'eighth=0.5'],
#  ['E5', 'eighth=0.75'],
#  ['C#6', '16th=0.25'],
#  ['B5', '16th=0.25'],
#  ['F#5', 'complex=1.25'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['G#5', 'eighth=0.75'],
#  ['B-5', 'eighth=0.5'],
#  ['B-5', '16th=0.25'],
#  ['B5', 'quarter=1.5'],
#  ['B5', 'quarter=1.75'],
#  ['C#5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E5', '16th=0.25'],
#  ['F#5', '16th=0.25'],
#  ['E-5', 'eighth=0.75'],
#  ['C#5', 'eighth=0.5'],
#  ['C#5', '16th=0.25'],
#  ['B4', 'quarter=1.5'],
#  ['B4', 'quarter=1.75'],
#  ['E5', '16th=0.25'],
#  ['E5', 'eighth=1/3'],
#  ['E-5', '16th=0.25'],
#  ['E5', 'eighth=1/3'],
#  ['F#5', 'eighth=0.75'],
#  ['G#5', 'complex=1.25'],
#  ['B-5', 'quarter=1.0'],
#  ['B5', 'quarter=1.0'],
#  ['B5', 'half=2.0'],
#  ['B5', 'quarter=1.5'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '32nd=1/12'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['F5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', 'eighth=0.5'],
#  ['E-5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['C5', '16th=0.25'],
#  ['B-4', 'eighth=0.5'],
#  ['C5', 'half=2.0'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '32nd=1/12'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['F5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', 'eighth=0.5'],
#  ['E-5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['F5', 'eighth=0.5'],
#  ['F5', 'half=2.0'],
#  ['B-5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['G5', 'eighth=1/3'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['C6', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['F5', 'eighth=1/3'],
#  ['A5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['G5', '16th=0.25'],
#  ['E-5', 'eighth=0.5'],
#  ['G5', '16th=0.25'],
#  ['G5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['G5', '16th=0.25'],
#  ['F5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['D5', 'eighth=0.5'],
#  ['D5', '16th=0.25'],
#  ['E-5', 'eighth=0.5'],
#  ['E-5', '16th=1/6'],
#  ['F5', '16th=0.25'],
#  ['A5', 'eighth=0.5'],
#  ['A5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['G5', 'eighth=0.5'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['C6', 'eighth=0.5'],
#  ['B-5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['F5', 'eighth=0.5'],
#  ['A5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['A5', 'eighth=0.5'],
#  ['A5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['G5', '16th=0.25'],
#  ['E-5', 'eighth=0.5'],
#  ['G5', '16th=0.25'],
#  ['G5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['G5', '16th=0.25'],
#  ['F5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['D5', 'quarter=2/3'],
#  ['D5', '16th=0.25'],
#  ['E-5', 'eighth=0.5'],
#  ['E-5', '16th=0.25'],
#  ['F5', 'eighth=0.5'],
#  ['B-5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['B-5', 'eighth=1/3'],
#  ['A5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['A5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['C6', '16th=0.25'],
#  ['A5', 'eighth=0.5'],
#  ['G5', '16th=0.25'],
#  ['A5', 'eighth=0.5'],
#  ['G5', '16th=0.25'],
#  ['A5', 'eighth=1/3'],
#  ['A5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['G5', 'eighth=0.5'],
#  ['F5', '16th=0.25'],
#  ['G5', 'eighth=0.5'],
#  ['F5', '16th=0.25'],
#  ['G5', 'eighth=1/3'],
#  ['G5', '16th=0.25'],
#  ['G5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['F5', 'eighth=0.5'],
#  ['E-5', '16th=0.25'],
#  ['F5', 'eighth=0.5'],
#  ['E-5', '16th=0.25'],
#  ['F5', 'eighth=1/3'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['A5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['A5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['C6', '16th=0.25'],
#  ['A5', 'eighth=0.5'],
#  ['G5', '16th=0.25'],
#  ['A5', 'eighth=0.5'],
#  ['G5', '16th=0.25'],
#  ['A5', 'eighth=1/3'],
#  ['G5', '16th=0.25'],
#  ['G5', '16th=0.25'],
#  ['F5', 'eighth=0.5'],
#  ['G5', 'quarter=1.0'],
#  ['F5', 'quarter=1.0'],
#  ['B-5', 'eighth=0.75'],
#  ['G5', 'half=2.0'],
#  ['G5', 'quarter=2/3'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '32nd=1/12'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['F5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', 'eighth=0.5'],
#  ['E-5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['C5', '16th=0.25'],
#  ['B-4', 'eighth=0.5'],
#  ['C5', 'half=2.0'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '32nd=1/12'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['F5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', 'eighth=0.5'],
#  ['E-5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['D5', '16th=0.25'],
#  ['F5', 'eighth=0.5'],
#  ['F5', 'half=2.0'],
#  ['B-5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['G5', 'eighth=1/3'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['C6', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['F5', 'eighth=1/3'],
#  ['A5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['G5', '16th=0.25'],
#  ['E-5', 'eighth=0.5'],
#  ['G5', '16th=0.25'],
#  ['G5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['G5', '16th=0.25'],
#  ['F5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['D5', 'eighth=0.5'],
#  ['D5', '16th=0.25'],
#  ['E-5', 'eighth=0.5'],
#  ['E-5', '16th=1/6'],
#  ['F5', '16th=0.25'],
#  ['A5', 'eighth=0.5'],
#  ['A5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['G5', 'eighth=0.5'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['C6', 'eighth=0.5'],
#  ['B-5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['F5', 'eighth=0.5'],
#  ['A5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['A5', 'eighth=0.5'],
#  ['A5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['G5', '16th=0.25'],
#  ['E-5', 'eighth=0.5'],
#  ['G5', '16th=0.25'],
#  ['G5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['G5', '16th=0.25'],
#  ['F5', '16th=0.25'],
#  ['E-5', '16th=0.25'],
#  ['D5', 'quarter=2/3'],
#  ['D5', '16th=0.25'],
#  ['E-5', 'eighth=0.5'],
#  ['E-5', '16th=0.25'],
#  ['F5', 'eighth=0.5'],
#  ['B-5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['B-5', 'eighth=1/3'],
#  ['A5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['A5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['C6', '16th=0.25'],
#  ['A5', 'eighth=0.5'],
#  ['G5', '16th=0.25'],
#  ['A5', 'eighth=0.5'],
#  ['G5', '16th=0.25'],
#  ['A5', 'eighth=1/3'],
#  ['A5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['G5', 'eighth=0.5'],
#  ['F5', '16th=0.25'],
#  ['G5', 'eighth=0.5'],
#  ['F5', '16th=0.25'],
#  ['G5', 'eighth=1/3'],
#  ['G5', '16th=0.25'],
#  ['G5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['F5', 'eighth=0.5'],
#  ['E-5', '16th=0.25'],
#  ['F5', 'eighth=0.5'],
#  ['E-5', '16th=0.25'],
#  ['F5', 'eighth=1/3'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['A5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['A5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['A5', '16th=0.25'],
#  ['B-5', 'eighth=0.5'],
#  ['B-5', '16th=0.25'],
#  ['B-5', '16th=0.25'],
#  ['C6', '16th=0.25'],
#  ['A5', 'eighth=0.5'],
#  ['G5', '16th=0.25'],
#  ...]

# %%
notes_frequency = {}
duration_frequency = {}

for notes in notes_array:
    if notes[0] not in notes_frequency:
        notes_frequency[notes[0]] = 0
    notes_frequency[notes[0]]+=1
    if notes[1] not in duration_frequency:
        duration_frequency[notes[1]] = 0
    duration_frequency[notes[1]]+=1

# %%
notes_frequency =  {key: val for key, val in sorted(notes_frequency.items(), key = lambda ele: -ele[1])}
notes_frequency
# Out:
# {'D5': 5989,
#  'B4': 5304,
#  'C5': 5188,
#  'E5': 5003,
#  'A4': 4812,
#  'E-5': 4625,
#  'G4': 4441,
#  'C#5': 4385,
#  'F5': 4283,
#  'B-4': 4238,
#  'G5': 4178,
#  'F#5': 3738,
#  'G#4': 3147,
#  'G#5': 2767,
#  'F#4': 2560,
#  'A5': 2502,
#  'F4': 2497,
#  'E4': 2286,
#  'D4': 1977,
#  'E-4': 1807,
#  'B-5': 1665,
#  'B5': 1663,
#  'C6': 1281,
#  'C4': 980,
#  'D6': 846,
#  'C#4': 844,
#  'B3': 631,
#  'C#6': 591,
#  'E6': 550,
#  'A3': 484,
#  'E-6': 440,
#  'B-3': 371,
#  'F6': 330,
#  'G3': 298,
#  'G#3': 168,
#  'G6': 133,
#  'F#6': 128,
#  'G#6': 75,
#  'E3': 62,
#  'A6': 52,
#  'F3': 47,
#  'F#3': 28,
#  'C7': 16,
#  'E-3': 14,
#  'B6': 9,
#  'D3': 4,
#  'D7': 3}

# %%
duration_frequency =   {key: val for key, val in sorted(duration_frequency.items(), key = lambda ele: -ele[1])}
duration_frequency
# Out:
# {'16th=0.25': 35281,
#  'eighth=0.5': 15862,
#  'eighth=1/3': 11699,
#  'quarter=1.0': 8636,
#  'eighth=0.75': 4959,
#  'quarter=2/3': 3674,
#  '16th=1/6': 2082,
#  '32nd=1/12': 1808,
#  'eighth=5/12': 931,
#  'half=2.0': 366,
#  'quarter=1.5': 337,
#  'complex=1.25': 324,
#  'quarter=7/12': 240,
#  'quarter=1.75': 207,
#  'quarter=5/6': 206,
#  'quarter=11/12': 153,
#  'half=4/3': 142,
#  'half=5/3': 121,
#  'half=3.0': 52,
#  'complex=2.5': 36,
#  'whole=4.0': 36,
#  'complex=2.25': 35,
#  'half=7/6': 34,
#  'half=3.75': 32,
#  'half=13/12': 28,
#  'half=3.5': 22,
#  'whole=8/3': 22,
#  'whole=7/3': 17,
#  'half=11/6': 14,
#  'complex=2.75': 13,
#  'complex=3.25': 13,
#  'whole=11/3': 13,
#  'half=19/12': 10,
#  'whole=10/3': 10,
#  'half=17/12': 8,
#  'whole=29/12': 8,
#  'half=23/12': 4,
#  'whole=13/6': 4,
#  'whole=25/12': 1}

# %%
best_music = unparsed_notes_array[0]

# %%
best_music_notes_array = []
for element in best_music[0]:
    if isinstance(element, note.Note):
        d = duration.Duration()
        d.quarterLength = element.quarterLength
        best_music_notes_array.append([str(element.pitch),  f"{d.type}={element.quarterLength}"])
best_music_notes_array
# Out:
# [['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', 'quarter=1.0'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'eighth=0.75'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'complex=1.25'],
#  ['F#4', 'quarter=2/3'],
#  ['F#4', 'eighth=0.5'],
#  ['F4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F4', 'eighth=1/3'],
#  ['F4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['E-4', 'eighth=0.75'],
#  ['E-4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['F#4', 'eighth=0.75'],
#  ['F#4', 'quarter=2/3'],
#  ['F4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['C#4', 'quarter=1.75'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'quarter=2/3'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F#4', 'half=13/12'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F#4', 'half=5/3'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', 'quarter=1.0'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'eighth=0.75'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', 'eighth=0.5'],
#  ['B-4', 'complex=1.25'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', 'quarter=1.0'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'eighth=0.75'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'complex=1.25'],
#  ['F#4', 'quarter=2/3'],
#  ['F#4', 'eighth=0.5'],
#  ['F4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F4', 'eighth=1/3'],
#  ['F4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['E-4', 'eighth=0.75'],
#  ['E-4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['F#4', 'eighth=0.75'],
#  ['F#4', 'quarter=2/3'],
#  ['F4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['C#4', 'quarter=1.75'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'quarter=2/3'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F#4', 'half=13/12'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['F#4', 'half=5/3'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', 'quarter=1.0'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'eighth=0.75'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', 'eighth=0.5'],
#  ['B-4', 'complex=1.25'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', 'quarter=1.0'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'eighth=0.75'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'complex=1.25'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', 'quarter=1.0'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'eighth=0.75'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', 'eighth=0.5'],
#  ['B-4', 'complex=1.25'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', 'quarter=1.0'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'eighth=0.75'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'complex=1.25'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', 'quarter=1.0'],
#  ['G#4', '16th=0.25'],
#  ['F4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'eighth=0.75'],
#  ['C#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['B-4', '16th=0.25'],
#  ['F#4', '16th=0.25'],
#  ['E-4', '16th=0.25'],
#  ['G#4', 'eighth=0.5'],
#  ['G#4', '16th=0.25'],
#  ['C#4', '16th=0.25'],
#  ['G#4', '16th=0.25'],
#  ['F#4', 'eighth=0.5'],
#  ['F#4', 'complex=1.25']]

# %%
best_music_notes_frequency = {}
best_music_duration_frequency = {}

for notes in best_music_notes_array:
    if notes[0] not in best_music_notes_frequency:
        best_music_notes_frequency[notes[0]] = 0
    best_music_notes_frequency[notes[0]]+=1
    if notes[1] not in best_music_duration_frequency:
        best_music_duration_frequency[notes[1]] = 0
    best_music_duration_frequency[notes[1]]+=1

# %%
best_music_duration_frequency
# Out:
# {'16th=0.25': 224,
#  'eighth=0.5': 36,
#  'quarter=1.0': 8,
#  'eighth=0.75': 12,
#  'complex=1.25': 8,
#  'quarter=2/3': 6,
#  'eighth=1/3': 2,
#  'quarter=1.75': 2,
#  'half=13/12': 2,
#  'half=5/3': 2}

# %%
best_music_notes_frequency
# Out:
# {'C#4': 40, 'E-4': 42, 'F#4': 88, 'G#4': 78, 'B-4': 30, 'F4': 24}

# %%
for index, note in enumerate(best_music_notes_array):
    print(index, note[0], note[1])
# Out:
# 0 C#4 16th=0.25
# 1 E-4 16th=0.25
# 2 F#4 16th=0.25
# 3 G#4 16th=0.25
# 4 B-4 16th=0.25
# 5 F#4 16th=0.25
# 6 E-4 16th=0.25
# 7 G#4 eighth=0.5
# 8 G#4 quarter=1.0
# 9 G#4 16th=0.25
# 10 F4 16th=0.25
# 11 C#4 16th=0.25
# 12 F#4 eighth=0.5
# 13 F#4 eighth=0.75
# 14 C#4 16th=0.25
# 15 E-4 16th=0.25
# 16 F#4 16th=0.25
# 17 G#4 16th=0.25
# 18 B-4 16th=0.25
# 19 F#4 16th=0.25
# 20 E-4 16th=0.25
# 21 G#4 eighth=0.5
# 22 G#4 16th=0.25
# 23 C#4 16th=0.25
# 24 G#4 16th=0.25
# 25 F#4 eighth=0.5
# 26 F#4 complex=1.25
# 27 F#4 quarter=2/3
# 28 F#4 eighth=0.5
# 29 F4 16th=0.25
# 30 F#4 16th=0.25
# 31 F4 eighth=1/3
# 32 F4 16th=0.25
# 33 F#4 16th=0.25
# 34 F4 16th=0.25
# 35 C#4 16th=0.25
# 36 E-4 16th=0.25
# 37 E-4 eighth=0.75
# 38 E-4 16th=0.25
# 39 F4 16th=0.25
# 40 F#4 eighth=0.75
# 41 F#4 quarter=2/3
# 42 F4 16th=0.25
# 43 F#4 16th=0.25
# 44 F4 16th=0.25
# 45 E-4 16th=0.25
# 46 C#4 16th=0.25
# 47 C#4 quarter=1.75
# 48 F#4 eighth=0.5
# 49 F#4 quarter=2/3
# 50 G#4 16th=0.25
# 51 B-4 16th=0.25
# 52 G#4 16th=0.25
# 53 G#4 16th=0.25
# 54 B-4 16th=0.25
# 55 G#4 16th=0.25
# 56 F4 16th=0.25
# 57 F#4 16th=0.25
# 58 F#4 half=13/12
# 59 C#4 16th=0.25
# 60 E-4 16th=0.25
# 61 F#4 16th=0.25
# 62 B-4 16th=0.25
# 63 G#4 16th=0.25
# 64 F#4 16th=0.25
# 65 G#4 16th=0.25
# 66 B-4 16th=0.25
# 67 G#4 16th=0.25
# 68 F#4 16th=0.25
# 69 F#4 half=5/3
# 70 C#4 16th=0.25
# 71 E-4 16th=0.25
# 72 F#4 16th=0.25
# 73 G#4 16th=0.25
# 74 B-4 16th=0.25
# 75 F#4 16th=0.25
# 76 E-4 16th=0.25
# 77 G#4 eighth=0.5
# 78 G#4 quarter=1.0
# 79 G#4 16th=0.25
# 80 F4 16th=0.25
# 81 C#4 16th=0.25
# 82 F#4 eighth=0.5
# 83 F#4 eighth=0.75
# 84 C#4 16th=0.25
# 85 E-4 16th=0.25
# 86 F#4 16th=0.25
# 87 G#4 16th=0.25
# 88 B-4 16th=0.25
# 89 F#4 16th=0.25
# 90 E-4 16th=0.25
# 91 G#4 eighth=0.5
# 92 G#4 16th=0.25
# 93 C#4 16th=0.25
# 94 G#4 16th=0.25
# 95 B-4 eighth=0.5
# 96 B-4 complex=1.25
# 97 C#4 16th=0.25
# 98 E-4 16th=0.25
# 99 F#4 16th=0.25
# 100 G#4 16th=0.25
# 101 B-4 16th=0.25
# 102 F#4 16th=0.25
# 103 E-4 16th=0.25
# 104 G#4 eighth=0.5
# 105 G#4 quarter=1.0
# 106 G#4 16th=0.25
# 107 F4 16th=0.25
# 108 C#4 16th=0.25
# 109 F#4 eighth=0.5
# 110 F#4 eighth=0.75
# 111 C#4 16th=0.25
# 112 E-4 16th=0.25
# 113 F#4 16th=0.25
# 114 G#4 16th=0.25
# 115 B-4 16th=0.25
# 116 F#4 16th=0.25
# 117 E-4 16th=0.25
# 118 G#4 eighth=0.5
# 119 G#4 16th=0.25
# 120 C#4 16th=0.25
# 121 G#4 16th=0.25
# 122 F#4 eighth=0.5
# 123 F#4 complex=1.25
# 124 F#4 quarter=2/3
# 125 F#4 eighth=0.5
# 126 F4 16th=0.25
# 127 F#4 16th=0.25
# 128 F4 eighth=1/3
# 129 F4 16th=0.25
# 130 F#4 16th=0.25
# 131 F4 16th=0.25
# 132 C#4 16th=0.25
# 133 E-4 16th=0.25
# 134 E-4 eighth=0.75
# 135 E-4 16th=0.25
# 136 F4 16th=0.25
# 137 F#4 eighth=0.75
# 138 F#4 quarter=2/3
# 139 F4 16th=0.25
# 140 F#4 16th=0.25
# 141 F4 16th=0.25
# 142 E-4 16th=0.25
# 143 C#4 16th=0.25
# 144 C#4 quarter=1.75
# 145 F#4 eighth=0.5
# 146 F#4 quarter=2/3
# 147 G#4 16th=0.25
# 148 B-4 16th=0.25
# 149 G#4 16th=0.25
# 150 G#4 16th=0.25
# 151 B-4 16th=0.25
# 152 G#4 16th=0.25
# 153 F4 16th=0.25
# 154 F#4 16th=0.25
# 155 F#4 half=13/12
# 156 C#4 16th=0.25
# 157 E-4 16th=0.25
# 158 F#4 16th=0.25
# 159 B-4 16th=0.25
# 160 G#4 16th=0.25
# 161 F#4 16th=0.25
# 162 G#4 16th=0.25
# 163 B-4 16th=0.25
# 164 G#4 16th=0.25
# 165 F#4 16th=0.25
# 166 F#4 half=5/3
# 167 C#4 16th=0.25
# 168 E-4 16th=0.25
# 169 F#4 16th=0.25
# 170 G#4 16th=0.25
# 171 B-4 16th=0.25
# 172 F#4 16th=0.25
# 173 E-4 16th=0.25
# 174 G#4 eighth=0.5
# 175 G#4 quarter=1.0
# 176 G#4 16th=0.25
# 177 F4 16th=0.25
# 178 C#4 16th=0.25
# 179 F#4 eighth=0.5
# 180 F#4 eighth=0.75
# 181 C#4 16th=0.25
# 182 E-4 16th=0.25
# 183 F#4 16th=0.25
# 184 G#4 16th=0.25
# 185 B-4 16th=0.25
# 186 F#4 16th=0.25
# 187 E-4 16th=0.25
# 188 G#4 eighth=0.5
# 189 G#4 16th=0.25
# 190 C#4 16th=0.25
# 191 G#4 16th=0.25
# 192 B-4 eighth=0.5
# 193 B-4 complex=1.25
# 194 C#4 16th=0.25
# 195 E-4 16th=0.25
# 196 F#4 16th=0.25
# 197 G#4 16th=0.25
# 198 B-4 16th=0.25
# 199 F#4 16th=0.25
# 200 E-4 16th=0.25
# 201 G#4 eighth=0.5
# 202 G#4 quarter=1.0
# 203 G#4 16th=0.25
# 204 F4 16th=0.25
# 205 C#4 16th=0.25
# 206 F#4 eighth=0.5
# 207 F#4 eighth=0.75
# 208 C#4 16th=0.25
# 209 E-4 16th=0.25
# 210 F#4 16th=0.25
# 211 G#4 16th=0.25
# 212 B-4 16th=0.25
# 213 F#4 16th=0.25
# 214 E-4 16th=0.25
# 215 G#4 eighth=0.5
# 216 G#4 16th=0.25
# 217 C#4 16th=0.25
# 218 G#4 16th=0.25
# 219 F#4 eighth=0.5
# 220 F#4 complex=1.25
# 221 C#4 16th=0.25
# 222 E-4 16th=0.25
# 223 F#4 16th=0.25
# 224 G#4 16th=0.25
# 225 B-4 16th=0.25
# 226 F#4 16th=0.25
# 227 E-4 16th=0.25
# 228 G#4 eighth=0.5
# 229 G#4 quarter=1.0
# 230 G#4 16th=0.25
# 231 F4 16th=0.25
# 232 C#4 16th=0.25
# 233 F#4 eighth=0.5
# 234 F#4 eighth=0.75
# 235 C#4 16th=0.25
# 236 E-4 16th=0.25
# 237 F#4 16th=0.25
# 238 G#4 16th=0.25
# 239 B-4 16th=0.25
# 240 F#4 16th=0.25
# 241 E-4 16th=0.25
# 242 G#4 eighth=0.5
# 243 G#4 16th=0.25
# 244 C#4 16th=0.25
# 245 G#4 16th=0.25
# 246 B-4 eighth=0.5
# 247 B-4 complex=1.25
# 248 C#4 16th=0.25
# 249 E-4 16th=0.25
# 250 F#4 16th=0.25
# 251 G#4 16th=0.25
# 252 B-4 16th=0.25
# 253 F#4 16th=0.25
# 254 E-4 16th=0.25
# 255 G#4 eighth=0.5
# 256 G#4 quarter=1.0
# 257 G#4 16th=0.25
# 258 F4 16th=0.25
# 259 C#4 16th=0.25
# 260 F#4 eighth=0.5
# 261 F#4 eighth=0.75
# 262 C#4 16th=0.25
# 263 E-4 16th=0.25
# 264 F#4 16th=0.25
# 265 G#4 16th=0.25
# 266 B-4 16th=0.25
# 267 F#4 16th=0.25
# 268 E-4 16th=0.25
# 269 G#4 eighth=0.5
# 270 G#4 16th=0.25
# 271 C#4 16th=0.25
# 272 G#4 16th=0.25
# 273 F#4 eighth=0.5
# 274 F#4 complex=1.25
# 275 C#4 16th=0.25
# 276 E-4 16th=0.25
# 277 F#4 16th=0.25
# 278 G#4 16th=0.25
# 279 B-4 16th=0.25
# 280 F#4 16th=0.25
# 281 E-4 16th=0.25
# 282 G#4 eighth=0.5
# 283 G#4 quarter=1.0
# 284 G#4 16th=0.25
# 285 F4 16th=0.25
# 286 C#4 16th=0.25
# 287 F#4 eighth=0.5
# 288 F#4 eighth=0.75
# 289 C#4 16th=0.25
# 290 E-4 16th=0.25
# 291 F#4 16th=0.25
# 292 G#4 16th=0.25
# 293 B-4 16th=0.25
# 294 F#4 16th=0.25
# 295 E-4 16th=0.25
# 296 G#4 eighth=0.5
# 297 G#4 16th=0.25
# 298 C#4 16th=0.25
# 299 G#4 16th=0.25
# 300 F#4 eighth=0.5
# 301 F#4 complex=1.25
