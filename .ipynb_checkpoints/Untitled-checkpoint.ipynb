# %%
from music21 import *
# for listing down the file names
import os


# Array Processing
import numpy as np

# %%
# defining function to read MIDI files
def read_midi(file):
    print("Loading Music File:", file)

    notes = []
    notes_to_parse = None

    # parsing a midi file
    midi = converter.parse(file)

    # grouping based on different instruments
    s2 = instrument.partitionByInstrument(midi)

    # Looping over all the instruments
    for part in s2.parts:

        # select elements of only piano
        if 'MELODY' in str(part):

            notes_to_parse = part.recurse()

            # finding whether a particular element is note or a chord
            for element in notes_to_parse:

                # note
                if isinstance(element, note.Note):
                    notes.append(str(element.pitch))

                # chord
                elif isinstance(element, chord.Chord):
                    notes.append('.'.join(str(n) for n in element.normalOrder))

    return np.array(notes)

# %%
# specify the path
path = 'POP/'

# read all the filenames
files = [i for i in os.listdir(path) if i.endswith(".mid")]

# reading each midi file
notes_array = np.array([read_midi(path + i) for i in files])
# Out:
# Loading Music File: schubert/schu_143_1.mid
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-8fd70503bb8f> in <module>
#       6
#       7 # reading each midi file
# ----> 8 notes_array = np.array([read_midi(path + i) for i in files])
#
# <ipython-input-7-8fd70503bb8f> in <listcomp>(.0)
#       6
#       7 # reading each midi file
# ----> 8 notes_array = np.array([read_midi(path + i) for i in files])
#
# <ipython-input-5-76ee5eb74cae> in read_midi(file)
#       7
#       8     # parsing a midi file
# ----> 9     midi = converter.parse(file)
#      10
#      11     # grouping based on different instruments
#
# ~\anaconda3\lib\site-packages\music21\converter\__init__.py in parse(value, *args, **keywords)
#    1166     elif (not isinstance(value, bytes)
#    1167           and _osCanLoad(valueStr)):
# -> 1168         return parseFile(valueStr, number=number, format=m21Format,
#    1169                          forceSource=forceSource, **keywords)
#    1170     elif (not isinstance(value, bytes)
#
# ~\anaconda3\lib\site-packages\music21\converter\__init__.py in parseFile(fp, number, format, forceSource, **keywords)
#    1035     v = Converter()
#    1036     fp = common.cleanpath(fp, returnPathlib=True)
# -> 1037     v.parseFile(fp, number=number, format=format, forceSource=forceSource, **keywords)
#    1038     return v.stream
#    1039
#
# ~\anaconda3\lib\site-packages\music21\converter\__init__.py in parseFile(self, fp, number, format, forceSource, storePickle, **keywords)
#     569         else:
#     570             environLocal.printDebug('Loading original version')
# --> 571             self.parseFileNoPickle(fp, number, format, forceSource, **keywords)
#     572             if writePickle is True and fpPickle is not None and storePickle is True:
#     573                 # save the stream to disk...
#
# ~\anaconda3\lib\site-packages\music21\converter\__init__.py in parseFileNoPickle(self, fp, number, format, forceSource, **keywords)
#     502         self.subConverter.keywords = keywords
#     503         try:
# --> 504             self.subConverter.parseFile(fp, number=number, **keywords)
#     505         except NotImplementedError:
#     506             raise ConverterFileException(f'File is not in a correct format: {fp}')
#
# ~\anaconda3\lib\site-packages\music21\converter\subConverters.py in parseFile(self, fp, number, **keywords)
#    1134         '''
#    1135         from music21.midi import translate as midiTranslate
# -> 1136         midiTranslate.midiFilePathToStream(fp, self.stream, **keywords)
#    1137
#    1138     def write(self, obj, fmt, fp=None, subformats=None, **keywords):  # pragma: no cover
#
# ~\anaconda3\lib\site-packages\music21\midi\translate.py in midiFilePathToStream(filePath, inputM21, **keywords)
#    2600     mf.read()
#    2601     mf.close()
# -> 2602     return midiFileToStream(mf, inputM21, **keywords)
#    2603
#    2604
#
# ~\anaconda3\lib\site-packages\music21\midi\translate.py in midiFileToStream(mf, inputM21, quantizePost, **keywords)
#    2771     # create a stream for each tracks
#    2772     # may need to check if tracks actually have event data
# -> 2773     midiTracksToStreams(mf.tracks,
#    2774                         ticksPerQuarter=mf.ticksPerQuarterNote,
#    2775                         quantizePost=quantizePost,
#
# ~\anaconda3\lib\site-packages\music21\midi\translate.py in midiTracksToStreams(midiTracks, ticksPerQuarter, quantizePost, inputM21, **keywords)
#    2511             streamPart = conductorPart
#    2512
# -> 2513         midiTrackToStream(mt,
#    2514                           ticksPerQuarter,
#    2515                           quantizePost,
#
# ~\anaconda3\lib\site-packages\music21\midi\translate.py in midiTrackToStream(mt, ticksPerQuarter, quantizePost, inputM21, conductorPart, isFirst, **keywords)
#    2003     s.makeTies(inPlace=True)
#    2004     # always need to fill gaps, as rests are not found in any other way
# -> 2005     s.makeRests(inPlace=True, fillGaps=True, timeRangeFromBarDuration=True)
#    2006     return s
#    2007
#
# ~\anaconda3\lib\site-packages\music21\stream\base.py in makeRests(self, refStreamOrTimeRange, fillGaps, timeRangeFromBarDuration, inPlace, hideRests)
#    6499         Changed in v.7, inPlace=False by default.
#    6500         '''
# -> 6501         return makeNotation.makeRests(
#    6502             self,
#    6503             refStreamOrTimeRange=refStreamOrTimeRange,
#
# ~\anaconda3\lib\site-packages\music21\stream\makeNotation.py in makeRests(s, refStreamOrTimeRange, fillGaps, timeRangeFromBarDuration, inPlace, hideRests)
#     961     if returnObj.hasMeasures():
#     962         # split rests at measure boundaries
# --> 963         returnObj.makeTies(classFilterList=(note.Rest,), inPlace=True)
#     964
#     965         # reposition measures
#
# ~\anaconda3\lib\site-packages\music21\stream\base.py in makeTies(self, meterStream, inPlace, displayTiedAccidentals, classFilterList)
#    6520         Added in v.7, `classFilterList`.
#    6521         '''
# -> 6522         return makeNotation.makeTies(
#    6523             self,
#    6524             meterStream=meterStream,
#
# ~\anaconda3\lib\site-packages\music21\stream\makeNotation.py in makeTies(s, meterStream, inPlace, displayTiedAccidentals, classFilterList)
#    1188
#    1189     # get measures from this stream
# -> 1190     measureStream = returnObj.getElementsByClass('Measure')
#    1191     if not measureStream:
#    1192         raise stream.StreamException(
#
# ~\anaconda3\lib\site-packages\music21\stream\base.py in getElementsByClass(self, classFilterList)
#    3382         25
#    3383         '''
# -> 3384         return self.iter().getElementsByClass(classFilterList, returnClone=False)
#    3385
#    3386     def getElementsNotOfClass(self, classFilterList) -> iterator.StreamIterator:
#
# ~\anaconda3\lib\site-packages\music21\stream\base.py in iter(self)
#     387         to add custom filters to an iterative search before iterating.
#     388         '''
# --> 389         return self.__iter__()
#     390
#     391     def __getitem__(self, k):
#
# ~\anaconda3\lib\site-packages\music21\stream\base.py in __iter__(self)
#     374         adds necessary Stream-specific features.
#     375         '''
# --> 376         return iterator.StreamIterator(self)
#     377
#     378     @property
#
# ~\anaconda3\lib\site-packages\music21\stream\iterator.py in __init__(self, srcStream, filterList, restoreActiveSites, activeInformation, ignoreSorting)
#     109                  ignoreSorting: bool = False):
#     110         if not ignoreSorting and srcStream.isSorted is False and srcStream.autoSort:
# --> 111             srcStream.sort()
#     112         self.srcStream: 'music21.stream.Stream' = srcStream
#     113         self.index: int = 0
#
# ~\anaconda3\lib\site-packages\music21\stream\base.py in sort(self, force)
#    7441         # experimental
#    7442         if (not self.isSorted and self._mutable) or force:
# -> 7443             self._elements.sort(key=lambda x: x.sortTuple(self))
#    7444             self._endElements.sort(key=lambda x: x.sortTuple(self))
#    7445
#
# ~\anaconda3\lib\site-packages\music21\stream\base.py in <lambda>(x)
#    7441         # experimental
#    7442         if (not self.isSorted and self._mutable) or force:
# -> 7443             self._elements.sort(key=lambda x: x.sortTuple(self))
#    7444             self._endElements.sort(key=lambda x: x.sortTuple(self))
#    7445
#
# ~\anaconda3\lib\site-packages\music21\base.py in sortTuple(self, useSite, raiseExceptionOnMiss)
#    2513             atEnd = 0
#    2514
# -> 2515         if self.duration.isGrace:
#    2516             isNotGrace = 0
#    2517         else:
#
# ~\anaconda3\lib\site-packages\music21\stream\base.py in _getDuration(self)
#    8292         else:
#    8293             # environLocal.printDebug(['creating new duration based on highest time'])
# -> 8294             self._cache['Duration'] = duration.Duration(quarterLength=self.highestTime)
#    8295             return self._cache['Duration']
#    8296
#
# ~\anaconda3\lib\site-packages\music21\stream\base.py in highestTime(self)
#    8216             #     isSorted would be true, but highestTime should be 4.0 not 0.25
#    8217             for e in self._elements:
# -> 8218                 candidateOffset = (self.elementOffset(e)
#    8219                                    + e.duration.quarterLength)
#    8220                 if candidateOffset > highestTimeSoFar:
#
# ~\anaconda3\lib\site-packages\music21\stream\base.py in elementOffset(self, element, returnSpecial)
#    1965
#    1966         # OffsetSpecial.__contains__() is more expensive, so try to fail fast
# -> 1967         if isinstance(o, str) and returnSpecial is False and o in OffsetSpecial:
#    1968             try:
#    1969                 return getattr(self, o)
#
# KeyboardInterrupt:
